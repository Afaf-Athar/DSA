# %% [markdown]
# #### show_list

# %%
string = 'aabbaacdecc'


char_count  = {}

for i in string:

    if i in char_count:
        char_count[i] +=1
    else:
        char_count[i] =1

max_value = 0
for key,values in char_count.items():
    # print(values)
    # print(max_value)
    if( values > max_value):

        max_value = values

        print(max_value)
        print(key)
# Out:
# 4
# a

# %%
char_count
# Out:
# {'a': 4, 'b': 2, 'c': 3, 'd': 1, 'e': 1}

# %%
string = 'I am one level up to next level'

st = string[::-1]

# %%
st
# Out:
# 'level txen ot pu level eno ma I'

# %%
df['NotNull'].isna()

# %%
mean  = df['NotNull']

# %%
df['NotNull'].fillna(mean,in)

# %%
filterdf = df[df['NotNull'].isna()]

# %%
class singleNode:

    def __init__(self,val):
        self.val = val
        self.ptr = None
        
def show_list(head):
    
    while(head != None):
        print(head.val)
        head = head.ptr
        
def create_list(nums):
    head = link(0,nums)
    return head


def link(index,nums):
    if(index == len(nums)):
        return None
    
    node = singleNode(nums[index])
    node.ptr = link(index+1,nums)

    return node

# %%
nums = [95,96,97,43,45,32,98]
create_list = create_list(nums)
show_list(create_list)
# created_list = show_list(nums)
# created_list
# print(created_list.val)
# sec = created_list.ptr
# print(sec.val)
# Out:
# 95
# 96
# 97
# 43
# 45
# 32
# 98

# %%
def containsDuplicate(nums):


    seen = {}

    for i in nums:
        if i in seen:
            seen[i] += 1
        else:
            seen[i] = 1

    print(seen)

    for key,value in seen.items():
        # print(key,value)
        if (value>1):

            print(key,value)
            return True

    return False

# %%
# nums = [2,2,1,1,1,2,2,3,3]
# nums = [3,2,3]
# nums = [2,2,1,1,1,2,2]
# nums = [1,2,3,4]
nums = [1,2,3,1]
# nums =[2,14,18,22,22]


containsDuplicate = containsDuplicate(nums)
containsDuplicate
