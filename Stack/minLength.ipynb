# %% [markdown]
# #### Is Minimum Length

# %%
from collections import deque

def minLength(s): 
    
    my_stack = deque()
    for i in s:
        my_stack.append(i)
    # print(my_stack)

    rev_string = []
    for i in my_stack:
        if((i=='B') and (my_stack[-1]== 'A') and (len(my_stack)!=0)):
            print(my_stack[-1])
            # my_stack.pop()

# %%
s = "ABFCACDB"
minLength = minLength(s)
minLength
