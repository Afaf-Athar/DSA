# %% [markdown]
# 581. Shortest Unsorted Continuous Subarray
#
# https://leetcode.com/problems/shortest-unsorted-continuous-subarray/description/?envType=problem-list-v2&envId=xleo1moc

# %%
def findUnsortedSubarray(nums):
    if len(nums)==1:
        return 0

# %%
nums = [2,6,4,8,10,9,15]

findUnsortedSubarray = findUnsortedSubarray(nums)
findUnsortedSubarray
# Out:
# [0, 1, 1, 2]
# 2
