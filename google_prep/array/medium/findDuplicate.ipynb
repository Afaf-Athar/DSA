# %% [markdown]
# 287. Find the Duplicate Number
#
# https://leetcode.com/problems/find-the-duplicate-number/description/?envType=problem-list-v2&envId=xleo1moc

# %%
def findDuplicate(nums):

    arr = [0] * (len(nums))
    count = "X"
    for i in nums:
        if i not in arr:
            arr[i] = arr[i] + 1
            print("if",i)

        else:

            arr[i] += 1
            # pass
            # print(arr.index(i))     
            print("else",i)   
    return nums[:1],arr

nums = [3,1,3,4,2]
# nums = [3,3,3,3,3]

findDuplicate = findDuplicate(nums)
findDuplicate
# Out:
# if 3
# else 1
# if 3
# if 4
# else 2
# ([3], [0, 1, 1, 2, 1])

# %%
# nums =[1,3,4,2,2]
nums = [3,1,3,4,2]
# nums = [3,3,3,3,3]

findDuplicate = findDuplicate(nums)
findDuplicate
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/nr/ylk2j3hx7yz7460520wq9pt00000gn/T/ipykernel_97772/3890931326.py in <module>
#       3 # nums = [3,3,3,3,3]
#       4
# ----> 5 findDuplicate = findDuplicate(nums)
#       6 findDuplicate
#
# /var/folders/nr/ylk2j3hx7yz7460520wq9pt00000gn/T/ipykernel_97772/1732511268.py in findDuplicate(nums)
#       5     for i in nums:
#       6         if i not in arr:
# ----> 7             arr[i] = arr[i] + 'arr[i]'
#       8             print("if",i)
#       9
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'
