# %% [markdown]
# 268. Missing Number
#
# https://leetcode.com/problems/missing-number/description/?envType=problem-list-v2&envId=xleo1moc

# %%
def missingNumber(nums):
    # if len(nums)==0:
        #     return 0
        
        # seen = {}
        # count = 1
        # for i in range(len(nums)+1):
        #     if i not in seen:
        #         seen[i] = 1
        
        # # print(seen)

        # for i in seen:
        #     if i not in nums:
        #         return i
        
        if len(nums)==0:
            return 0
        
        num2 = []
        i = 0
        for i in range(len(nums)+1):
            num2.append(i)

        unique_num = list(set(nums))
        unique_num2 = list(set(num2))

        for i in unique_num2:
            if i not in unique_num:

                return i

# %%
# nums = [3,0,1]
nums = [0,1]

missingNumber = missingNumber(nums)
missingNumber
# Out:
# 2
