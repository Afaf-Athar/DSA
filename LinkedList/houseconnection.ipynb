# %% [markdown]
# #### houseconnection

# %%
class House:

    def __init__(self,name,houseNo):
        self.name = name
        self.houseNo = houseNo
        self.nextdoor = None


def houseconnection():
    punit = House("Punit",1000)
    rabbani = House("Rabbani",1001)
    kishan = House("Kishan",1002)

    punit.nextdoor = rabbani
    rabbani.nextdoor = kishan

    route = punit
    while(route!=None):
        print(route.name)
        route =  route.nextdoor

def houserecur(nums,index):
    punit = House(nums[index],index)
    punit.nextdoor = houserecur(nums,index+1)

# %% [markdown]
# #### recursive

# %%
class House:

    def __init__(self,name,houseNo):
        self.name = name
        self.houseNo = houseNo
        self.nextdoor = None


def houseconnection(nums):


    route = houserecur(nums,0)
    while(route!=None):
        print(route.name)
        route =  route.nextdoor

def houserecur(nums,index):
    if(index ==  len(nums)):
        return None
    
    house = House(nums[index],index)
    house.nextdoor = houserecur(nums,index+1)
    return house

# %%
nums = ["punit","rabbani","kishan"]
print(houseconnection(nums))
# Out:
# punit
# rabbani
# kishan
# None

# %%
class railwayStation:
    
    def __init__(self,name,noPlat):
        self.name = name
        self.noPlat = noPlat
        self.tracks = None

def connectionstationroute1():
    Delhi = railwayStation("Delhi",9)
    Kanpur = railwayStation("Kanpur",3)
    Bihar = railwayStation("Bihar",6)
    
    # print(Delhi.name)
    Delhi.tracks = Kanpur
    # print(Kanpur.name)
    Kanpur.tracks = Bihar
    # print(Bihar.name)

    Station = Delhi
    while(Station!=None):
        print(Station.name)
        Station = Station.tracks

def connectionstationroute2():
    Delhi = railwayStation("Delhi",9)
    Kanpur = railwayStation("Kanpur",3)
    Bihar = railwayStation("Bihar",6)
    
    # print(Delhi.name)
    Bihar.tracks = Kanpur
    # print(Kanpur.name)
    Kanpur.tracks = Delhi
    # print(Bihar.name)

    Station = Bihar
    while(Station!=None):
        print(Station.name)
        Station = Station.tracks


def connectionstationroute3():
    Delhi = railwayStation("Delhi",9)
    Kanpur = railwayStation("Kanpur",3)
    Bihar = railwayStation("Bihar",6)
    Lucknow = railwayStation("Lucknow",4)
    
    Bihar.tracks = Kanpur
    Kanpur.tracks = Lucknow
    Lucknow.tracks = Delhi

    Station = Bihar
    while(Station!=None):
        print(Station.name)
        Station = Station.tracks

# %%
# print(connectionstationroute1())
val = connectionstationroute1()
val
# Out:
# Delhi
# Kanpur
# Bihar

# %%
# print(connectionstationroute2())
val2 = connectionstationroute2()
val2
# Out:
# Bihar
# Kanpur
# Delhi

# %%
val3 = connectionstationroute3()
val3
# Out:
# Bihar
# Kanpur
# Lucknow
# Delhi

# %%
# class singleNode:

#     def __init__(self,val):
#         self.val = val
#         self.ptr = None
        
# def deleteDuplicates(head):
    
#     while(head != None):
#         print(head.val)
#         head = head.ptr
        
# def create_list(nums):
#     head = deleteDuplicatesNums(0,nums)
#     return head


# def deleteDuplicatesNums(index,nums):
#     if(index == len(nums)):
#         return None
    
#     if(nums[index]== nums[index+1]):
#         i = i+1
#     else:

    
#     node = singleNode(nums[index])

#     node.ptr = deleteDuplicatesNums(index+1,nums)

#     return node

# %%
# class singleNode:

#     def __init__(self,value):
#         self.value = value
#         self.pointer = None

# def deleteDuplicatesNums(head):

#     if (head.pointer==None):
#         return None
    
#     head = head.value
#     nextNode = head.ptr

#     if(head != nextNode.value):
#         head = nextNode.value
#         nextNode = nextNode.ptr

# %%
nums = [95,96,97,95,96,97,43,45,32,98]
create_list = create_list(nums)
# deleteDuplicates(create_list)
# created_list = deleteDuplicates(nums)
# created_list
# print(created_list.val)
# sec = created_list.ptr
# print(sec.val)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/nr/ylk2j3hx7yz7460520wq9pt00000gn/T/ipykernel_19999/2621886670.py in <module>
#       1 nums = [95,96,97,95,96,97,43,45,32,98]
# ----> 2 create_list = create_list(nums)
#       3 # deleteDuplicates(create_list)
#       4 # created_list = deleteDuplicates(nums)
#       5 # created_list
#
# /var/folders/nr/ylk2j3hx7yz7460520wq9pt00000gn/T/ipykernel_19999/52758572.py in create_list(head)
#       8
#       9     while(head!=None):
# ---> 10         print(head.value)
#      11         head = head.pointer
#
# AttributeError: 'list' object has no attribute 'value'

# %%
def containsDuplicate(nums):


    seen = {}

    for i in nums:
        if i in seen:
            seen[i] += 1
        else:
            seen[i] = 1

    print(seen)

    for key,value in seen.items():
        # print(key,value)
        if (value>1):

            print(key,value)
            return True

    return False

# %%
# nums = [2,2,1,1,1,2,2,3,3]
# nums = [3,2,3]
# nums = [2,2,1,1,1,2,2]
# nums = [1,2,3,4]
nums = [1,2,3,1]
# nums =[2,14,18,22,22]


containsDuplicate = containsDuplicate(nums)
containsDuplicate
